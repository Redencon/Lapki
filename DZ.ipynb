# %% [markdown]
# # Double Zond

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Измерение производяься в дипазоне напряжений на электродах от 200 до 400 В с шагом 50
#
# Сопротивление резистора, на котором измеряется ток: 9.1 кОм

# %%
data = pd.DataFrame([
    {'Uv, V': -77.7, 'Ui, V': -.613, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -64.3, 'Ui, V': -.555, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -45.4, 'Ui, V': -.471, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -33.7, 'Ui, V': -.415, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -18.3, 'Ui, V': -.333, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -08.2, 'Ui, V': -.244, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +02.9, 'Ui, V': +.079, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +07.2, 'Ui, V': +.183, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +11.8, 'Ui, V': +.243, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +17.4, 'Ui, V': +.279, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +22.2, 'Ui, V': +.304, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +28.9, 'Ui, V': +.335, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +33.5, 'Ui, V': +.356, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +37.9, 'Ui, V': +.375, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +43.1, 'Ui, V': +.398, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +50.5, 'Ui, V': +.428, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +57.0, 'Ui, V': +.455, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +59.8, 'Ui, V': +.466, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +63.2, 'Ui, V': +.479, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +64.8, 'Ui, V': +.485, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +67.6, 'Ui, V': +.496, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +70.9, 'Ui, V': +.509, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +75.3, 'Ui, V': +.525, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +77.6, 'Ui, V': +.533, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +00.1, 'Ui, V': +.016, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +03.8, 'Ui, V': +.146, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -06.6, 'Ui, V': -.213, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -09.0, 'Ui, V': -.256, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -11.4, 'Ui, V': -.282, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +01.5, 'Ui, V': +.029, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': +03.9, 'Ui, V': +.105, 'p, mkbar': 62.9, 'Uvch, V': 203},
    {'Uv, V': -02.4, 'Ui, V': -.099, 'p, mkbar': 62.9, 'Uvch, V': 203},

    {'Uv, V': -67.3, 'Ui, V': -.651, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -57.3, 'Ui, V': -.603, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -47.8, 'Ui, V': -.555, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -37.5, 'Ui, V': -.501, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -27.9, 'Ui, V': -.449, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -17.8, 'Ui, V': -.388, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -07.6, 'Ui, V': -.281, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -03.8, 'Ui, V': -.173, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +00.6, 'Ui, V': +.004, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +05.3, 'Ui, V': +.176, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +12.8, 'Ui, V': +.302, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +23.3, 'Ui, V': +.365, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +33.5, 'Ui, V': +.417, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +43.9, 'Ui, V': +.467, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +53.2, 'Ui, V': +.510, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +63.3, 'Ui, V': +.554, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +73.2, 'Ui, V': +.597, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +76.6, 'Ui, V': +.611, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +08.0, 'Ui, V': +.239, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +06.5, 'Ui, V': +.204, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +02.1, 'Ui, V': +.063, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': +09.8, 'Ui, V': +.267, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -05.9, 'Ui, V': -.236, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -01.6, 'Ui, V': -.090, 'p, mkbar': 62.9, 'Uvch, V': 250},
    {'Uv, V': -12.0, 'Ui, V': -.340, 'p, mkbar': 62.9, 'Uvch, V': 250},

    {'Uv, V': -75.3, 'Ui, V': -.781, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -63.7, 'Ui, V': -.717, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -53.8, 'Ui, V': -.664, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -43.9, 'Ui, V': -.609, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -33.8, 'Ui, V': -.550, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -24.0, 'Ui, V': -.490, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -12.2, 'Ui, V': -.404, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -01.2, 'Ui, V': -.035, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +08.3, 'Ui, V': +.294, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +15.9, 'Ui, V': +.380, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +25.5, 'Ui, V': +.438, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +35.1, 'Ui, V': +.490, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +46.0, 'Ui, V': +.547, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +57.0, 'Ui, V': +.600, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +65.6, 'Ui, V': +.640, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +75.4, 'Ui, V': +.690, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +12.7, 'Ui, V': +.352, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +06.4, 'Ui, V': +.247, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': +03.5, 'Ui, V': +.146, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -01.2, 'Ui, V': -.075, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -04.6, 'Ui, V': -.230, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -06.2, 'Ui, V': -.288, 'p, mkbar': 62.9, 'Uvch, V': 300},
    {'Uv, V': -09.8, 'Ui, V': -.369, 'p, mkbar': 62.9, 'Uvch, V': 300},

    {'Uv, V': -74.3, 'Ui, V': -.851, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -64.8, 'Ui, V': -.789, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -55.1, 'Ui, V': -.734, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -44.8, 'Ui, V': -.684, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -34.8, 'Ui, V': -.623, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -24.8, 'Ui, V': -.558, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -16.4, 'Ui, V': -.498, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -10.3, 'Ui, V': -.426, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -07.7, 'Ui, V': -.370, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -05.0, 'Ui, V': -.279, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -00.8, 'Ui, V': -.061, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +02.8, 'Ui, V': +.141, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +05.1, 'Ui, V': +.240, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +07.6, 'Ui, V': +.319, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +10.4, 'Ui, V': +.377, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +12.2, 'Ui, V': +.400, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +20.7, 'Ui, V': +.470, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +30.6, 'Ui, V': +.533, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +40.0, 'Ui, V': +.586, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +50.5, 'Ui, V': +.645, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +60.7, 'Ui, V': +.697, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +70.1, 'Ui, V': +.747, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +74.0, 'Ui, V': +.767, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +00.4, 'Ui, V': +.008, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': +17.0, 'Ui, V': +.446, 'p, mkbar': 62.9, 'Uvch, V': 350},
    {'Uv, V': -04.0, 'Ui, V': -.230, 'p, mkbar': 62.9, 'Uvch, V': 350},

    {'Uv, V': -72.8, 'Ui, V': -.919, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -59.7, 'Ui, V': -.830, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -49.0, 'Ui, V': -.763, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -35.9, 'Ui, V': -.683, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -22.6, 'Ui, V': -.594, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -15.1, 'Ui, V': -.528, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -09.2, 'Ui, V': -.437, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -03.4, 'Ui, V': -.214, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': -00.3, 'Ui, V': -.028, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +00.0, 'Ui, V': -.009, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +03.3, 'Ui, V': +.177, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +07.7, 'Ui, V': +.361, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +15.2, 'Ui, V': +.475, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +24.7, 'Ui, V': +.558, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +37.1, 'Ui, V': +.643, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +48.0, 'Ui, V': +.704, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +56.4, 'Ui, V': +.753, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +65.4, 'Ui, V': +.806, 'p, mkbar': 62.9, 'Uvch, V': 400},
    {'Uv, V': +72.5, 'Ui, V': +.848, 'p, mkbar': 62.9, 'Uvch, V': 400},
])
data['Uv_real, V'] = data['Uv, V'] - data['Ui, V']
data['I, mA'] = data['Ui, V'] / 9.1
plt.figure(figsize=(12,8))
ax = plt.axes()
sns.scatterplot(data = data, x = 'Uv_real, V', y = 'I, mA', ax=ax, hue='Uvch, V', palette='viridis')

from matplotlib.ticker import MultipleLocator
plt.grid(which='major', color='#323232', linestyle='-')
plt.grid(which='minor', color='#a4a4a4', linestyle=':')
mlx = MultipleLocator(2)
ax.xaxis.set_minor_locator(mlx)
mly = MultipleLocator(0.05)
ax.yaxis.set_minor_locator(mly)
# data.to_csv('DZ.csv')

# %%
from scipy.optimize import curve_fit

# %%
data2 = pd.read_csv('DZ2.csv', sep=';')
plt.figure(figsize=(12, 8))
def comma_to_dot(s: str) -> str:
    if type(s) != str:
        return s
    a = ''
    for c in s:
        if c == ',':
            a += '.'
        else:
            a += c
    return a

data2 = data2.applymap(comma_to_dot).astype('float64')
data2['Uv_real, V'] = data2['Uv, V'] - data2['Ui, V']
data2['I, mA'] = data2['Ui, V'] / 9.1
ax = plt.axes()
sns.scatterplot(data = data2, x = 'Uv_real, V', y = 'I, mA', ax=ax, hue='Uvch, V', palette='winter', marker='o', label='300 мкбар')
sns.scatterplot(data = data, x = 'Uv_real, V', y = 'I, mA', ax=ax, hue='Uvch, V', palette='autumn', marker='o', label='60 мкбар')

ax.set_xlabel('Напряжение между электродами, В')
ax.set_ylabel('Ток между электродами')
ax.set_title('ВАХ двойного зонда')

from matplotlib.ticker import MultipleLocator
plt.grid(which='major', color='#323232', linestyle='-')
plt.grid(which='minor', color='#a4a4a4', linestyle=':')
mlx = MultipleLocator(2)
ax.xaxis.set_minor_locator(mlx)
mly = MultipleLocator(0.005)
ax.yaxis.set_minor_locator(mly)
# data.to_csv('DZ.csv')

# %%
def f(U, dU, T, I0, a, b):
    return I0 * np.tanh(1.6e-19*(U - dU)/(2*1.38e-23*T)) + a*U + b

Us = (203, 250, 300, 350, 400)
columns = ('Uvch', 'dU', 'T', 'I0, mA', 'a', 'b')
def hehehe(data, p0, func=f, cols = columns):
    plt.figure(figsize=(12, 8))
    ax = plt.axes()
    popt = []
    pcov = []
    for Uvch in p0:
        popti, pcovi = curve_fit(func, data[data['Uvch, V'] == Uvch]['Uv, V'], data[data['Uvch, V'] == Uvch]['I, mA'], maxfev=5000**2, p0=p0[Uvch])
        popt.append([Uvch] + list(popti))
        pcov.append([Uvch] + list(np.sqrt(pcovi.diagonal())))
        xs = np.linspace(-80, 80, 400)
        ys = func(xs, *popti)
        ax.plot(xs, ys, label=f'{Uvch} В')
        ax.scatter(data[data['Uvch, V'] == Uvch]['Uv, V'], data[data['Uvch, V'] == Uvch]['I, mA'])
    popts = pd.DataFrame(popt, columns=cols)
    pcovs = pd.DataFrame(pcov, columns=cols)
    return popts, pcovs, ax

popts, pcovs, ax = hehehe(data, {Uvch: (0, 1e5, 0, 0, 0) for Uvch in Us})
# popts['I0, A'] = popts['I0'] / 9.1e3
popts['n'] = 6.02e22 * popts['I0, mA']*1e-3 / np.sqrt(popts['T'])
popts['alpha'] = popts['n']/1.45e21
popts['d_alpha'] = np.sqrt(0.5*(pcovs['T'] / popts['T'])**2 + (pcovs['I0, mA']/popts['I0, mA'])) * popts['alpha']
popts['d_T'] = pcovs['T']
popts['d_n'] = np.sqrt(0.5*(pcovs['T'] / popts['T'])**2 + (pcovs['I0, mA']/popts['I0, mA'])) * popts['n']

ax.set_xlabel('Напряжение на зонде, В')
ax.set_ylabel('Ток на зонде, мА')
ax.set_title('ВАХ двойного зонда при давлении 60 мкбар')

from matplotlib.ticker import MultipleLocator
plt.grid(which='major', color='#323232', linestyle='-')
plt.grid(which='minor', color='#a4a4a4', linestyle=':')
mlx = MultipleLocator(2)
ax.xaxis.set_minor_locator(mlx)
mly = MultipleLocator(0.005)
ax.yaxis.set_minor_locator(mly)
# data.to_csv('DZ.csv')

ax.legend()

# %%
# dU, T, I0, a, b
p0 = {
    200: [0, 6e4, 2.2e-1 , 0, 0],
    250: [0, 10e4, 7e-2, 1e-3, -1e-2],
    300: [0, 6e4, 0.15, 1e-3, -1e-2],
    350: [0, 6e4, 0.27, 2e-3, -1e-2],
}

def funcer(params):
    def f(U, T):
        return T*U
    return f


""" def hehehe2(data, p0, cols = columns):
    plt.figure(figsize=(12, 8))
    popt = []
    pcov = []
    for Uvch in p0:
        popti, pcovi = curve_fit(lambda U, T: U*T, data[data['Uvch, V'] == Uvch]['Uv, V'], data[data['Uvch, V'] == Uvch]['Ui, V'], maxfev=5000**2, p0=(1e-3))
        popt.append([Uvch] + list(popti))
        pcov.append([Uvch] + list(np.sqrt(pcovi.diagonal())))
        xs = np.linspace(-80, 80, 400)
        ys = xs * popti[-1]

        plt.scatter(data[data['Uvch, V'] == Uvch]['Uv, V'], data[data['Uvch, V'] == Uvch]['Ui, V'])
        plt.scatter(data[data['Uvch, V'] == Uvch]['Uv, V'], funcer(p0[Uvch][1:])(data[data['Uvch, V'] == Uvch]['Uv, V'], *popti), color='black')
    popts = pd.DataFrame(popt, columns=cols)
    pcovs = pd.DataFrame(pcov, columns=cols)
    return popts, pcovs """

def f_ez(U, T, I0, a, b):
    return I0 * np.tanh(1.6e-19*(U)/(2*1.38e-23*T)) + a*U + b

popts2, pcovs2, ax =  hehehe(data2, p0)

# popts1, pcovs1 = hehehe(data, p0=(5e-1, 4e4, 0.2, 4e-3, 1e-2))

# popts2

# plt.figure(figsize=(12, 8))
# popt, pcov = curve_fit(f, data2[data2['Uvch, V'] == 200]['Uv, V'], data2[data2['Uvch, V'] == 200]['Ui, V'], p0=(0.6, 1e5, 5e-2, -2e-5, -3e-4), maxfev=10**8)
# for i in [1e3, 5e3, 1e4, 6e4, 1e5, 1e6, 6e6, 6e5]:
#     xs = np.linspace(-80, 80, 500)
#     ys = f(xs, *[0, i, 1e-2, 1e-4, 0])
#     plt.plot(xs, ys)
# plt.scatter(data2[data2['Uvch, V'] == 200]['Uv, V'], data2[data2['Uvch, V'] == 200]['Ui, V'])
# popts2['I0, A'] = popts2['I0'] / 9.1e3

from matplotlib.ticker import MultipleLocator
plt.grid(which='major', color='#323232', linestyle='-')
plt.grid(which='minor', color='#a4a4a4', linestyle=':')
mlx = MultipleLocator(2)
ax.xaxis.set_minor_locator(mlx)
mly = MultipleLocator(0.002)
ax.yaxis.set_minor_locator(mly)
# data.to_csv('DZ.csv')
popts2['n'] = 6.02e22 * popts2['I0, mA']*1e-3 / np.sqrt(popts['T'])
popts2['alpha'] = popts2['n']/1.45e21
popts2['d_alpha'] = np.sqrt(0.5*(pcovs2['T'] / popts2['T'])**2 + (pcovs2['I0, mA']/popts2['I0, mA'])) * popts2['alpha']
popts2['d_T'] = pcovs2['T']
popts2['d_n'] = np.sqrt(0.5*(pcovs2['T'] / popts2['T'])**2 + (pcovs2['I0, mA']/popts2['I0, mA'])) * popts2['n']

ax.set_xlabel('Напряжение на зонде, В')
ax.set_ylabel('Ток через зонд, мА')
ax.set_title('ВАХ двойного зонда при давлении 300 мкбар')
ax.legend()

# %%
plt.figure(figsize=(12, 8))
ax = plt.axes()
plt.scatter(data=popts, x='Uvch', y='alpha', label='60 мкбар')
plt.scatter(data=popts2, x='Uvch', y='alpha', label='300 мкбар')
plt.errorbar(x = popts2['Uvch'], y=popts2['alpha'], yerr=popts2['d_alpha'], linestyle='', color='k')
plt.errorbar(x = popts['Uvch'], y=popts['alpha'], yerr=popts['d_alpha'], linestyle='', color='k')
plt.xlabel('Напряжение накала, В')
plt.ylabel('Степень ионизации')

from matplotlib.ticker import MultipleLocator
plt.grid(which='major', color='#323232', linestyle='-')
plt.grid(which='minor', color='#a4a4a4', linestyle=':')
mlx = MultipleLocator(5)
ax.xaxis.set_minor_locator(mlx)
mly = MultipleLocator(5e-7)
ax.yaxis.set_minor_locator(mly)
# data.to_csv('DZ.csv')

linf = lambda x, k, b: k*x + b

kbs, dkbs = curve_fit(linf, popts['Uvch'], popts['alpha'], sigma=popts['d_alpha'])
kbs2, dkbs2 = curve_fit(linf, popts2['Uvch'], popts2['alpha'], sigma=popts2['d_alpha'])

xs = np.linspace(195, 405, 100)
ys1 = linf(xs, *kbs)
ys2 = linf(xs, *kbs2)

ax.plot(xs, ys1, label='60 мкбар')
ax.plot(xs, ys2, label='300 мкбар')
ax.legend()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(data=popts, x='Uvch', y='T', label='p = 60 мкбар')
sns.scatterplot(data=popts2, x='Uvch', y='T', label='p = 300 мкбар')

plt.errorbar(data=popts, x='Uvch', y='T', yerr='d_T', linestyle='', label=None)
plt.errorbar(data=popts2, x='Uvch', y='T', yerr='d_T', linestyle='', label=None)

plt.ylabel('Температура, К')
plt.xlabel('Напряжение накала, В')
plt.legend()

# %%
kbs
# Out:
# array([2.15995454e-08, 8.41539632e-07])

# %%
def table(pp: pd.DataFrame, p):
    for ind in pp.index:
        print(p, end=' & ')
        print(round(pp['Uvch'][ind]), end=' & ')
        print(round(pp['T'][ind]), end=' & ')
        print(round(pp['d_T'][ind]), end=' & ')
        print(round(pp['n'][ind]*1e-15, 2), end=' & ')
        print(round(pp['d_n'][ind]*1e-15, 2), end=' & ')
        print(round(pp['alpha'][ind]*1e7, 2), end=' & ')
        print(round(pp['d_alpha'][ind]*1e7, 2), end='\\\\\n')

labels = (r'p, мкбар', r'Uвч, В', r'T, К', r'\sigma T, К', r'n \cdot 10^{-15}, м^{-3}', r'\sigma n \cdot 10^{-15}, м^{-3}', r'\alpha \cdot 10^{7}', r'\sigma \alpha \cdot 10^{7}')
print(*labels, sep=' & ', end='\\\\ \n')
table(popts, 60)
table(popts2, 300)
# Out:
# p, мкбар & Uвч, В & T, К & \sigma T, К & n \cdot 10^{-15}, м^{-3} & \sigma n \cdot 10^{-15}, м^{-3} & \alpha \cdot 10^{7} & \sigma \alpha \cdot 10^{7}\\
# 60 & 203 & 45092 & 2319 & 7.49 & 1.24 & 51.65 & 8.54\\
# 60 & 250 & 44300 & 1314 & 9.01 & 1.15 & 62.15 & 7.91\\
# 60 & 300 & 43019 & 1839 & 10.76 & 1.58 & 74.2 & 10.87\\
# 60 & 350 & 43292 & 644 & 12.41 & 1.06 & 85.58 & 7.33\\
# 60 & 400 & 44674 & 958 & 13.45 & 1.33 & 92.74 & 9.14\\
# 300 & 200 & 52376 & 5408 & 1.23 & 0.29 & 8.49 & 2.01\\
# 300 & 250 & 53581 & 5048 & 2.29 & 0.52 & 15.77 & 3.57\\
# 300 & 300 & 65322 & 2206 & 5.34 & 0.74 & 36.81 & 5.12\\
# 300 & 350 & 61764 & 4433 & 8.84 & 1.76 & 60.96 & 12.12\\

# %%
data2[data2['Uvch, V'] == 350].plot(y='Ui, V', x='Uv, V', linestyle='', marker='o', color='k')
# Out:
# <AxesSubplot:xlabel='Uv, V'>

# %%
pcovs2
# Out:
#    Uvch        dU            T    I0, mA         a         b
# 0   200  0.463867  5407.809457  0.000220  0.000004  0.000072
# 1   250  0.413210  5047.502142  0.000374  0.000007  0.000121
# 2   300  0.151952  2206.056301  0.000346  0.000006  0.000096
# 3   350  0.265294  4433.167317  0.001129  0.000020  0.000303
